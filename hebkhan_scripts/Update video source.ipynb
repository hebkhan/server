# %%
from mining import init_remote_api, batch_iter
init_remote_api("hebkhan")

from google.appengine.ext import db
import models
# Out:
# WARNING:root:webapp2_extras.local is not available so webapp2 won't be thread-safe!

# %%
def maybe_khan(vid):
    return all((not vid.source,
                vid.youtube_id,
                vid.youtube_id_en,
                vid.youtube_id != vid.youtube_id_en))

from collections import defaultdict

vids = [vid 
        for vid in batch_iter(models.Video.all().filter("source =", None))
        if maybe_khan(vid)]
# Out:
# Batch 1000 :
# Batch
#  418 :

# %%
print len(vids)
khan_sample = vids[::13]
for v in khan_sample:
    print "http://youtu.be/" + v.youtube_id, v.youtube_id_en, v.title
# Out:
# 178
# http://youtu.be/d7ornMJb8GA rEtuPhl6930 חוקי חזקות חלק 2
# http://youtu.be/NFffoQoDjRI XoEn1LfVoTo משוואות 2
# http://youtu.be/GryUZ0UU1jc 9Ek61w1LxSc משוואות פשוטות
# http://youtu.be/CBlYayl7YAE iorZdz4dsBU כפל וחילוק עם ספרות ערך
# http://youtu.be/opUN_WUgELE IReD6c_njOY משוואות פרמטריות 4
# http://youtu.be/L1sOx-lWGkE t3cJYNdQLYg אינטגרל קווי  בשדה וקטורים
# http://youtu.be/STVQGf4nNgU K_fgnCJOI8I אי תלות המסלול באינטגרל קוי
# http://youtu.be/xV03T80qVGo X6zD3SoN3iY תכונות החזקות 4
# http://youtu.be/y5HVT-TkqM8 3GL69IA2q4s הכפלה וחילוק של ביטויים רציונליים 1
# http://youtu.be/MeKA1MldEmM 4F6cFLnAAFc ביטויים של חזקות שברים 2
# http://youtu.be/IWOL7UKwCic bQ-KR3clFgs חלוקת מספרים חיוביים ושליליים
# http://youtu.be/yZFewbAPzFI O1N2rENXq_Y תפקיד הפגוציטים בחיסון מולד לא ספציפי
# http://youtu.be/7XDsU6nAciQ liRNTieIU_k דוגמה: פרוק לגורמים של תלת איבר ריבועי
# http://youtu.be/-ORCKYq7Yu8 kw_4Loo1HR4 שימור אנרגיה

# %%
for v in sorted(vids, key=lambda vid: vid.readable_id):
    v.source = "hebkhan"
db.put(vids)
# Out:
# [datastore_types.Key.from_path(u'Video', 59005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 59008L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 60006L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 60008L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 60010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 60013L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 60053L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 61009L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 61012L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 61015L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 61019L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 61022L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 62009L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 62011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 62012L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 64011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 64012L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 64015L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 64016L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 64042L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 65005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 65011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 65012L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 65016L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 66006L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 66009L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 66010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 66011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 66013L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 67011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 67012L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 67015L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 67016L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 67018L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 67036L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 69004L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 69006L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 69010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 70002L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 70005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 70010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 70012L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 70064L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 70066L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 70069L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 70126L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 71007L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 71011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 71012L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 71014L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 71085L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 72003L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 72005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 72013L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 72019L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 72024L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 72026L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 73002L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 73015L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 73016L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 73042L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 73045L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 75004L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 75010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 75013L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 76011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 76026L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 85007L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 138014L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 141002L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 141009L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 141011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 142003L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 143002L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 145003L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 146006L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 147007L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 150005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 150011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 151014L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 152005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 152031L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 152050L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 152062L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 152106L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 154013L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 154017L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 154021L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 154035L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 154041L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 154101L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 155031L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 155046L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 155086L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 156091L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 156092L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 157028L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 157043L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 157047L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 157050L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 158046L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 158079L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 159012L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 159016L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 159038L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 159044L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 159056L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 159058L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 159085L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 159111L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 160120L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 160121L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 161006L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 161009L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 161015L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 161026L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 161031L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 161035L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 161036L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 161059L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 164036L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 165011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 165023L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 165031L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 165032L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 165049L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 165094L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 166026L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 166061L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 167002L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 167005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 167015L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 167040L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 167069L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 167071L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 168004L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 168065L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 168091L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 168092L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 169033L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 169037L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 169057L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 169074L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 169104L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 187006L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 188012L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 189004L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 189006L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 189010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 189021L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 189027L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 190010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 190013L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 190024L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 190026L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 191005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 191018L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 192021L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 193010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 193015L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 193029L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 193033L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 194009L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 194011L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 194014L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 194025L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 195005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 195008L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 195009L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 195010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 196010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 197009L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 198022L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 199010L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 199031L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 200004L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 200005L, _app=u's~hebkhan'),
#  datastore_types.Key.from_path(u'Video', 201024L, _app=u's~hebkhan')]
